# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('dogs.csv')
df
# Out:
#                  breed  working_intelligence_level  obedience_pc  reps_avg  \
# 0               poodle                           5            95       2.5
# 1      german shepherd                           5            95       2.5
# 2     golden retriever                           5            95       2.5
# 3    doberman pinscher                           5            95       2.5
# 4    shetland sheepdog                           5            95       2.5
# ..                 ...                         ...           ...       ...
# 100     great pyrenees                           1            30      60.5
# 101   scottish terrier                           1            30      60.5
# 102       bull terrier                           1            30      60.5
# 103          chihuahua                           1            30      60.5
# 104        bullmastiff                           1            30      60.5
#
# ...

# %%
df['rank_2015'].value_counts()
# Out:
# rank_2015
# 8.0      1
# 122.0    1
# 79.0     1
# 45.0     1
# 13.0     1
#         ..
# 130.0    1
# 82.0     1
# 83.0     1
# 52.0     1
# 43.0     1
# Name: count, Length: 105, dtype: int64
