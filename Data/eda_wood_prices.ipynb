# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Data set selected is called "Wood Prices Dataset" and was obtained from Kaggle at https://www.kaggle.com/datasets/swarajkhan/wood-prices-dataset.
#
# **About:** This comprehensive dataset offers a detailed exploration of wood types from different regions, showcasing their market prices, popularity ratings, and various attributes. With over a thousand entries, this dataset is a valuable resource for understanding the dynamics of the international wood market, identifying trends in pricing, and uncovering factors that influence wood popularity. Whether you're a researcher, analyst, or enthusiast, this dataset provides a wealth of information for studying the global wood industry.

# %%
import numpy as np
import pandas as pd

# %%
# Load and view dataset.
df = pd.read_csv('./Data/wood_prices.csv')
print(f'Columns = {list(df.columns)}.')
df
# Out:
# Columns = ['Wood Type', 'Country', 'Price (USD)', 'Supply Source', 'Quality Rating', 'Popularity', 'Demand Level', 'Availability'].
#     Wood Type       Country  Price (USD) Supply Source Quality Rating  \
# 0       Maple         China       166.59      Imported         Medium
# 1    Rosewood  South Africa       144.71         Local            Low
# 2    Rosewood  South Africa       216.92         Local         Medium
# 3         Oak        Russia       130.13      Imported         Medium
# 4      Bamboo     Australia       114.66         Local         Medium
# ..        ...           ...          ...           ...            ...
# 995  Rosewood     Indonesia       151.81         Local         Medium
# 996      Pine       Germany       230.97      Imported            Low
# 997     Maple     Indonesia       200.87         Local            Low
# 998     Maple  South Africa       227.75      Imported            Low
# 999  Mahogany     Indonesia       122.71      Imported            Low
#
#      Popularity Demand Level Availability
# 0             3       Medium     Moderate
# 1             6       Medium     Moderate
# 2             2       Medium     Abundant
# 3             5          Low     Abundant
# 4             8          Low     Abundant
# ..          ...          ...          ...
# 995           2       Medium      Limited
# 996           4          Low     Abundant
# 997           4         High      Limited
# 998           8         High     Moderate
# 999           5          Low      Limited
#
# [1000 rows x 8 columns]

# %%
# View possible values for each column.
for column in df.columns:
    print(f'\nColumn "{column}":')
    vc = df[column].value_counts()
    print(vc)
    print(f'Count = {len(vc.keys())}')
# Out:
# Column "Wood Type":
# Wood Type
# Rosewood    134
# Teak        133
# Oak         130
# Maple       128
# Mahogany    124
# Pine        121
# Cedar       118
# Bamboo      112
# Name: count, dtype: int64
# Count = 8
#
# Column "Country":
# Country
# Brazil          125
# Australia       110
# Germany         110
# Russia          108
# China            99
# India            98
# Indonesia        96
# USA              95
# Canada           82
# South Africa     77
# Name: count, dtype: int64
# Count = 10
#
# Column "Price (USD)":
# Price (USD)
# 154.50    3
# 148.61    3
# 89.75     2
# 249.90    2
# 199.30    2
#          ..
# 85.45     1
# 195.80    1
# 129.52    1
# 119.82    1
# 122.71    1
# Name: count, Length: 971, dtype: int64
# Count = 971
#
# Column "Supply Source":
# Supply Source
# Imported    512
# Local       488
# Name: count, dtype: int64
# Count = 2
#
# Column "Quality Rating":
# Quality Rating
# Medium    366
# High      321
# Low       313
# Name: count, dtype: int64
# Count = 3
#
# Column "Popularity":
# Popularity
# 8     114
# 3     104
# 10    104
# 4     104
# 6     103
# 5     100
# 2      99
# 1      93
# 9      92
# 7      87
# Name: count, dtype: int64
# Count = 10
#
# Column "Demand Level":
# Demand Level
# Medium    349
# High      329
# Low       322
# Name: count, dtype: int64
# Count = 3
#
# Column "Availability":
# Availability
# Moderate    341
# Abundant    341
# Limited     318
# Name: count, dtype: int64
# Count = 3

# %% [markdown]
# <font color='#8888ff'>OBSERVATION:</font> This dataset has 8 columns and 1000 rows.
#
# |Attribute|Type|Meaning|
# |---|---|---|
# |Wood Type|Nominal Categorical Qualitative|Name of type of wood.|
# |Country|Nominal Categorical Qualitative|Name of country.|
# |Price (USD)|Interval/Ratio Continuous Quantitative|Market price of wood in US Dollars.|
# |Supply Source|Ordinal Categorical Qualitative|Whether wood is imported/locally sourced.|
# |Quality Rating|Ordinal Categorical Qualitative|Quality if wood (low, medium, high).|
# |Demand Level|Ordinal Categorical Qualitative|Demand for wood (low, medium, high).|
# |Availability|Ordinal Categorical Qualitative|How easily/plentifully is the wood available (limited, moderate, abundant)?|
# |Popularity|Discrete Quantitative|How popular the wood is [1,10]?|

# %%
df.drop(['Price (USD)'], axis=1).drop_duplicates()['Country'].value_counts()
# Out:
# Country
# Brazil          123
# Australia       108
# Germany         108
# Russia          106
# China            99
# India            97
# USA              95
# Indonesia        94
# Canada           81
# South Africa     76
# Name: count, dtype: int64

# %%
df[df['Country'] == 'Russia']['Wood Type'].value_counts()
# Out:
# Wood Type
# Rosewood    19
# Mahogany    17
# Bamboo      15
# Teak        14
# Pine        14
# Cedar       12
# Oak         10
# Maple        7
# Name: count, dtype: int64

# %%
df[
    (df['Wood Type'] == 'Bamboo')
    & (df['Country'] == 'China')
].drop(['Price (USD)'], axis=1).drop_duplicates()
# Out:
#     Wood Type Country Supply Source Quality Rating  Popularity Demand Level  \
# 60     Bamboo   China         Local         Medium          10       Medium
# 81     Bamboo   China      Imported         Medium           3         High
# 215    Bamboo   China         Local         Medium          10         High
# 379    Bamboo   China         Local           High           8          Low
# 422    Bamboo   China         Local            Low           9          Low
# 542    Bamboo   China      Imported         Medium          10          Low
# 585    Bamboo   China      Imported         Medium           8         High
# 612    Bamboo   China      Imported            Low           6         High
# 837    Bamboo   China         Local            Low           4       Medium
# 899    Bamboo   China      Imported            Low           8       Medium
# 907    Bamboo   China      Imported           High           4       Medium
# 948    Bamboo   China         Local         Medium           3         High
#
#     Availability
# 60       Limited
# 81      Moderate
# 215      Limited
# 379     Abundant
# 422      Limited
# 542     Abundant
# 585      Limited
# 612     Abundant
# 837      Limited
# 899      Limited
# 907      Limited
# 948     Abundant

# %%
df['Country'].value_counts()
# Out:
# Country
# Brazil          125
# Australia       110
# Germany         110
# Russia          108
# China            99
# India            98
# Indonesia        96
# USA              95
# Canada           82
# South Africa     77
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Wood Type', 'Country', 'Price (USD)', 'Supply Source',
#        'Quality Rating', 'Popularity', 'Demand Level', 'Availability'],
#       dtype='object')

# %%
df.drop(['Price (USD)'], axis=1).value_counts()
# Out:
# Wood Type  Country       Supply Source  Quality Rating  Popularity  Demand Level  Availability
# Cedar      Indonesia     Local          Low             2           Low           Limited         2
#            Australia     Imported       Low             6           Medium        Abundant        2
# Oak        India         Local          Low             1           Medium        Limited         2
# Mahogany   Russia        Local          Low             1           High          Moderate        2
# Rosewood   Russia        Imported       Low             8           Low           Limited         2
#                                                                                                  ..
# Mahogany   South Africa  Local          Medium          10          Low           Abundant        1
#            USA           Imported       Low             1           Low           Moderate        1
#                                                         8           Medium        Limited         1
#                                                         10          Low           Limited         1
# Teak       USA           Local          Medium          7           High          Moderate        1
# Name: count, Length: 987, dtype: int64

# %%
df[np.logical_and(df['Country'] == 'India', df['Wood Type'] == 'Maple')]
# Out:
#     Wood Type Country  Price (USD) Supply Source Quality Rating  Popularity  \
# 5       Maple   India       149.07      Imported            Low           6
# 42      Maple   India       121.48      Imported            Low           9
# 73      Maple   India       220.31         Local         Medium           3
# 146     Maple   India       222.80         Local         Medium           7
# 333     Maple   India       170.23         Local           High           8
# 426     Maple   India       126.93         Local           High           3
# 448     Maple   India       135.16      Imported           High           5
# 602     Maple   India        83.90      Imported           High           3
# 688     Maple   India       150.41      Imported            Low           2
# 720     Maple   India       159.59         Local            Low           1
# 932     Maple   India       221.32      Imported            Low           2
#
#     Demand Level Availability
# 5            Low     Moderate
# 42           Low      Limited
# 73           Low     Moderate
# 146         High     Abundant
# 333       Medium      Limited
# 426          Low     Moderate
# 448       Medium     Moderate
# 602         High     Abundant
# 688          Low     Abundant
# 720         High      Limited
# 932       Medium     Moderate
